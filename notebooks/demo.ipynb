# %% [markdown]
# # FutureLink HGT Demo
# Load the sample graph, inspect it, run the baseline, and view predictions.

# %%
from src.data.loader import load_graph_tables, graph_summary
tables = load_graph_tables('../data/raw')
graph_summary(tables)

# %%
from src.training.train import similarity_baseline
similarity_baseline('../data/raw', '../artifacts')

# %%
from src.inference import recommend_concepts
recommend_concepts(0, '../data/raw', top_k=5)
